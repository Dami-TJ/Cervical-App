# %%
import warnings
warnings.filterwarnings("ignore")
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # Comment out to enable GPU if desired

import pandas as pd
import numpy as np
import tensorflow as tf
from math import ceil
import matplotlib.pyplot as plt
import hashlib
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Function to load data
def load_data(dataset_dir):
    file_paths, labels = [], []
    has_subfolders = False
    for root, dirs, files in os.walk(dataset_dir):
        class_name = os.path.basename(root)
        if class_name == ".ipynb_checkpoints":
            continue
        if root != dataset_dir:
            has_subfolders = True
        image_files = [file for file in files if file.endswith((".jpg", ".png", ".jpeg"))]
        for file in image_files:
            try:
                file_path = os.path.join(root, file)
                with open(file_path, 'rb') as f:
                    _ = f.read()
                file_paths.append(file_path)
                labels.append(class_name if has_subfolders else None)
            except Exception as e:
                print(f"Error reading file {file_path}: {e}")
    df = pd.DataFrame({"file_path": file_paths, "label": labels})
    print(f"Loaded {len(df)} images from {dataset_dir}")
    print("Labels found:", df["label"].unique())
    if not has_subfolders:
        print(f"Warning: No class subfolders found in {dataset_dir}. 'label' column may be invalid.")
    return df

# Alternative load_data for flat directory with CSV labels (uncomment if needed)
"""
def load_data(dataset_dir, csv_path=None):
    file_paths, labels = [], []
    if csv_path:
        try:
            label_df = pd.read_csv(csv_path)
            print(f"Loaded CSV with {len(label_df)} entries from {csv_path}")
            for _, row in label_df.iterrows():
                file_path = os.path.join(dataset_dir, row['filename'])
                if os.path.exists(file_path) and file_path.endswith((".jpg", ".png", ".jpeg")):
                    try:
                        with open(file_path, 'rb') as f:
                            _ = f.read()
                        file_paths.append(file_path)
                        labels.append(str(row['label']))
                    except Exception as e:
                        print(f"Error reading file {file_path}: {e}")
        except Exception as e:
            print(f"Error reading CSV {csv_path}: {e}")
    else:
        has_subfolders = False
        for root, dirs, files in os.walk(dataset_dir):
            class_name = os.path.basename(root)
            if class_name == ".ipynb_checkpoints":
                continue
            if root != dataset_dir:
                has_subfolders = True
            image_files = [file for file in files if file.endswith((".jpg", ".png", ".jpeg"))]
            for file in image_files:
                try:
                    file_path = os.path.join(root, file)
                    with open(file_path, 'rb') as f:
                        _ = f.read()
                    file_paths.append(file_path)
                    labels.append(class_name if has_subfolders else None)
                except Exception as e:
                    print(f"Error reading file {file_path}: {e}")
    df = pd.DataFrame({"file_path": file_paths, "label": labels})
    print(f"Loaded {len(df)} images from {dataset_dir}")
    print("Labels found:", df["label"].unique())
    if not csv_path and not has_subfolders:
        print(f"Warning: No class subfolders found in {dataset_dir}. 'label' column may be invalid.")
    return df
"""

# Load original dataset
dataset_dir = "./data"
df = load_data(dataset_dir)
if df.empty or 'label' not in df.columns or df["label"].isna().all():
    raise ValueError("Original dataset is empty or missing valid 'label' column")
df['hash'] = df['file_path'].apply(lambda x: hashlib.md5(open(x, 'rb').read()).hexdigest())
print("Number of duplicates in original data:", df['hash'].duplicated().sum())
df = df.drop_duplicates(subset='hash').drop(columns='hash')
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Balance original dataset
class_counts = df["label"].value_counts()
print("Class Distribution Before Balancing:\n", class_counts)
min_samples = class_counts.min()
balanced_df = df.groupby("label").apply(lambda x: x.sample(min_samples, random_state=42)).reset_index(drop=True)
print("Class Distribution After Balancing:\n", balanced_df["label"].value_counts())

# Load new test dataset
new_test_dir = "./balanced2"
new_test_df = load_data(new_test_dir)
if new_test_df.empty or 'label' not in new_test_df.columns or new_test_df["label"].isna().all():
    raise ValueError("New test dataset is empty or missing valid 'label' column")
new_test_df['hash'] = new_test_df['file_path'].apply(lambda x: hashlib.md5(open(x, 'rb').read()).hexdigest())
print("Number of duplicates in new test data:", new_test_df['hash'].duplicated().sum())
new_test_df = new_test_df.drop_duplicates(subset='hash').drop(columns='hash')
print("New Test Data Class Distribution:\n", new_test_df["label"].value_counts())

# Load original test dataset
test_dir = "./test_data"
test_df = load_data(test_dir)
use_test_data = True
if test_df.empty or 'label' not in test_df.columns or test_df["label"].isna().all():
    print("Warning: Test dataset is empty or missing valid 'label' column. Skipping original test data evaluation.")
    use_test_data = False
else:
    test_df['hash'] = test_df['file_path'].apply(lambda x: hashlib.md5(open(x, 'rb').read()).hexdigest())
    print("Number of duplicates in test data:", test_df['hash'].duplicated().sum())
    test_df = test_df.drop_duplicates(subset='hash').drop(columns='hash')
    print("Test Data Class Distribution:\n", test_df["label"].value_counts())

# Parameters
IMG_SIZE = (224, 224)
CHANNELS = 3
IMG_SHAPE = (IMG_SIZE[0], IMG_SIZE[1], CHANNELS)
BATCH_SIZE = 64
TEST_BATCH_SIZE = BATCH_SIZE
EPOCHS = 10
K_FOLDS = 5
test_length = len(test_df) if use_test_data else 0

# Test data generator (only if test data is valid)
test_gen = None
if use_test_data:
    test_gen_aug = ImageDataGenerator(preprocessing_function=preprocess_input)
    test_gen = test_gen_aug.flow_from_dataframe(
        test_df, x_col="file_path", y_col="label",
        target_size=IMG_SIZE, batch_size=TEST_BATCH_SIZE, class_mode="categorical",
        shuffle=False, seed=42
    )

# K-Fold setup on original data
skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
all_train_acc, all_val_acc, all_train_loss, all_val_loss = [], [], [], []
fold_no = 1

# Create checkpoint directory
checkpoint_dir = "./checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

for train_index, val_index in skf.split(balanced_df["file_path"], balanced_df["label"]):
    print(f"\nTraining Fold {fold_no}/{K_FOLDS}")
    train_df, val_df = balanced_df.iloc[train_index], balanced_df.iloc[val_index]
    print("Training class distribution:\n", train_df['label'].value_counts())
    print("Validation class distribution:\n", val_df['label'].value_counts())
    
    # Data generators
    train_gen_aug = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.4,
        height_shift_range=0.4,
        shear_range=0.4,
        zoom_range=0.4,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest',
        preprocessing_function=preprocess_input
    )
    val_gen_aug = ImageDataGenerator(preprocessing_function=preprocess_input)
    
    train_gen = train_gen_aug.flow_from_dataframe(
        train_df, x_col="file_path", y_col="label",
        target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical",
        shuffle=True, seed=42
    )
    val_gen = val_gen_aug.flow_from_dataframe(
        val_df, x_col="file_path", y_col="label",
        target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical",
        shuffle=False, seed=42
    )
    
    # Check class consistency with test data (if available)
    if use_test_data and set(test_gen.class_indices.keys()) != set(train_gen.class_indices.keys()):
        raise ValueError("Class labels in original test data do not match training data classes.")
    
    # Model
    base_model = ResNet50(input_shape=IMG_SHAPE, weights='imagenet', include_top=False)
    for layer in base_model.layers:
        layer.trainable = True
    
    model = Sequential([
        base_model,
        Flatten(),
        BatchNormalization(),
        Dense(64, activation="relu", kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        BatchNormalization(),
        Dense(32, activation="relu", kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(len(train_gen.class_indices), activation="softmax")
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    
    # Callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    checkpoint = ModelCheckpoint(
        os.path.join(checkpoint_dir, f'best_model_fold_{fold_no}.keras'),
        save_best_only=True
    )
    
    # Training
    history = model.fit(
        train_gen, epochs=EPOCHS, validation_data=val_gen,
        callbacks=[early_stop, checkpoint], verbose=1
    )
    
    all_train_acc.append(history.history["accuracy"])
    all_val_acc.append(history.history["val_accuracy"])
    all_train_loss.append(history.history["loss"])
    all_val_loss.append(history.history["val_loss"])

    #orginal data confusion matrix
    y_pred = np.argmax(model.predict(val_gen), axis=1)
    y_true = val_gen.classes
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(cm, display_labels=val_gen.class_indices.keys())
    plt.figure(figsize=(6, 5))
    disp.plot(cmap="Blues", xticks_rotation=45)
    plt.title(f"Confusion Matrix - Fold {fold_no}")
    plt.show()
    plt.figure(figsize=(12, 5))

    # Plot cumulative training and validation metrics up to this fold
    plt.figure(figsize=(12, 5))
    
    # Training vs Validation Accuracy
    plt.subplot(1, 2, 1)
    for i in range(fold_no):
        epochs_range = range(1, len(all_train_acc[i]) + 1)
        plt.plot(epochs_range, all_train_acc[i], label=f"Train Fold {i+1}")
        plt.plot(epochs_range, all_val_acc[i], label=f"Val Fold {i+1}", linestyle="dashed")
    plt.title(f"Training & Validation Accuracy (Folds 1-{fold_no})")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    
    # Training vs Validation Loss
    plt.subplot(1, 2, 2)
    for i in range(fold_no):
        epochs_range = range(1, len(all_train_loss[i]) + 1)
        plt.plot(epochs_range, all_train_loss[i], label=f"Train Fold {i+1}")
        plt.plot(epochs_range, all_val_loss[i], label=f"Val Fold {i+1}", linestyle="dashed")
    plt.title(f"Training & Validation Loss (Folds 1-{fold_no})")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Test on new dataset
    print(f"\nTesting Fold {fold_no} on New Data...")
    new_test_gen = val_gen_aug.flow_from_dataframe(
        new_test_df, x_col="file_path", y_col="label",
        target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical",
        shuffle=False, seed=42
    )
    
    if set(new_test_gen.class_indices.keys()) != set(train_gen.class_indices.keys()):
        raise ValueError("Class labels in new test data do not match training data classes.")
    
    y_pred_new = np.argmax(model.predict(new_test_gen), axis=1)
    y_true_new = new_test_gen.classes
    cm_new = confusion_matrix(y_true_new, y_pred_new)
    disp_new = ConfusionMatrixDisplay(cm_new, display_labels=list(new_test_gen.class_indices.keys()))
    
    plt.figure(figsize=(6, 5))
    disp_new.plot(cmap="Blues", xticks_rotation=45)
    plt.title(f"Confusion Matrix - Fold {fold_no} (New Test Data)")
    plt.show()
    
    print(f"\nClassification Report - Fold {fold_no} (New Test Data):")
    print(classification_report(y_true_new, y_pred_new, target_names=list(new_test_gen.class_indices.keys())))
    
    # Test on original test data (if available)
    if use_test_data:
        print(f"\nTesting Fold {fold_no} on Original Test Data...")
        test_steps = ceil(test_length / TEST_BATCH_SIZE)
        test_score = model.evaluate(test_gen, steps=test_steps)
        print(f"Original Test Loss: {test_score[0]:.6f}")
        print(f"Original Test Accuracy: {round(test_score[1]*100)}%")
        
        Yhat = np.argmax(model.predict(test_gen, steps=test_steps), axis=1)
        Ytrue = test_gen.classes
        cm = confusion_matrix(Ytrue, Yhat)
        disp = ConfusionMatrixDisplay(cm, display_labels=list(test_gen.class_indices.keys()))
        
        fig, ax = plt.subplots(figsize=(10, 8))
        disp.plot(cmap="Blues", ax=ax)
        ax.grid(False)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
        plt.title(f"Confusion Matrix - Fold {fold_no} (Original Test Data)")
        plt.show()
        
        print("\nClassification Report - Original Test Data:")
        print(classification_report(Ytrue, Yhat, target_names=list(test_gen.class_indices.keys())))
    
    fold_no += 1

# Summary statistics
mean_val_acc = np.mean([acc[-1] for acc in all_val_acc])
std_val_acc = np.std([acc[-1] for acc in all_val_acc])
print(f"\nMean Validation Accuracy (Original Data): {mean_val_acc:.4f} ± {std_val_acc:.4f}")
# Out:
# Loaded 10000 images from ./data
# Labels found: ['Koilocytotic' 'Parabasal' 'Metaplastic' 'Dyskeratotic'
#  'Superficial-Intermediate']
# Number of duplicates in original data: 0
# Class Distribution Before Balancing:
#  label
# Dyskeratotic                2000
# Metaplastic                 2000
# Koilocytotic                2000
# Parabasal                   2000
# Superficial-Intermediate    2000
# Name: count, dtype: int64
# Class Distribution After Balancing:
#  label
# Dyskeratotic                2000
# Koilocytotic                2000
# Metaplastic                 2000
# Parabasal                   2000
# Superficial-Intermediate    2000
# Name: count, dtype: int64
# Loaded 500 images from ./balanced2
# Labels found: ['Koilocytotic' 'Parabasal' 'Metaplastic' 'Dyskeratotic'
#  'Superficial-Intermediate']
# Number of duplicates in new test data: 0
# New Test Data Class Distribution:
#  label
# Koilocytotic                100
# Parabasal                   100
# Metaplastic                 100
# Dyskeratotic                100
# Superficial-Intermediate    100
# Name: count, dtype: int64
# Loaded 0 images from ./test_data
# Labels found: []
# Warning: No class subfolders found in ./test_data. 'label' column may be invalid.
# Warning: Test dataset is empty or missing valid 'label' column. Skipping original test data evaluation.
#
# Training Fold 1/5
# Training class distribution:
#  label
# Dyskeratotic                1600
# Koilocytotic                1600
# Metaplastic                 1600
# Parabasal                   1600
# Superficial-Intermediate    1600
# Name: count, dtype: int64
# Validation class distribution:
#  label
# Dyskeratotic                400
# Koilocytotic                400
# Metaplastic                 400
# Parabasal                   400
# Superficial-Intermediate    400
# Name: count, dtype: int64
# Found 8000 validated image filenames belonging to 5 classes.
# Found 2000 validated image filenames belonging to 5 classes.
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 185s 897ms/step - accuracy: 0.5499 - loss: 2.8949 - val_accuracy: 0.9195 - val_loss: 1.9036
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 102s 814ms/step - accuracy: 0.8939 - loss: 2.0294 - val_accuracy: 0.9595 - val_loss: 1.6671
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 106s 850ms/step - accuracy: 0.9428 - loss: 1.7350 - val_accuracy: 0.9760 - val_loss: 1.4489
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9639 - loss: 1.5048 - val_accuracy: 0.9860 - val_loss: 1.2370
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 101s 804ms/step - accuracy: 0.9706 - loss: 1.2996 - val_accuracy: 0.9955 - val_loss: 1.0509
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 100s 802ms/step - accuracy: 0.9756 - loss: 1.1157 - val_accuracy: 0.9905 - val_loss: 0.9175
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 101s 808ms/step - accuracy: 0.9821 - loss: 0.9532 - val_accuracy: 0.9725 - val_loss: 0.8498
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9803 - loss: 0.8375 - val_accuracy: 0.9975 - val_loss: 0.6487
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9862 - loss: 0.6960 - val_accuracy: 0.9940 - val_loss: 0.5690
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 102s 814ms/step - accuracy: 0.9862 - loss: 0.6057 - val_accuracy: 0.9905 - val_loss: 0.5037
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 281ms/step
# Testing Fold 1 on New Data...
# Found 500 validated image filenames belonging to 5 classes.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 965ms/step
# Classification Report - Fold 1 (New Test Data):
#                           precision    recall  f1-score   support
#
#             Dyskeratotic       0.93      0.74      0.82       100
#             Koilocytotic       0.89      0.72      0.80       100
#              Metaplastic       0.73      0.86      0.79       100
#                Parabasal       0.88      1.00      0.94       100
# Superficial-Intermediate       0.93      1.00      0.96       100
#
#                 accuracy                           0.86       500
#                macro avg       0.87      0.86      0.86       500
#             weighted avg       0.87      0.86      0.86       500
#
#
# Training Fold 2/5
# Training class distribution:
#  label
# Dyskeratotic                1600
# Koilocytotic                1600
# Metaplastic                 1600
# Parabasal                   1600
# Superficial-Intermediate    1600
# Name: count, dtype: int64
# Validation class distribution:
#  label
# Dyskeratotic                400
# Koilocytotic                400
# Metaplastic                 400
# Parabasal                   400
# Superficial-Intermediate    400
# Name: count, dtype: int64
# Found 8000 validated image filenames belonging to 5 classes.
# Found 2000 validated image filenames belonging to 5 classes.
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.5279 - loss: 2.9589 - val_accuracy: 0.9030 - val_loss: 2.0206
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 124s 989ms/step - accuracy: 0.8772 - loss: 2.0482 - val_accuracy: 0.9605 - val_loss: 1.6794
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 100s 802ms/step - accuracy: 0.9414 - loss: 1.7418 - val_accuracy: 0.9420 - val_loss: 1.5191
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 101s 808ms/step - accuracy: 0.9622 - loss: 1.5066 - val_accuracy: 0.9890 - val_loss: 1.2297
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 104s 829ms/step - accuracy: 0.9709 - loss: 1.2897 - val_accuracy: 0.9960 - val_loss: 1.0295
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9797 - loss: 1.1052 - val_accuracy: 0.9910 - val_loss: 0.8866
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 102s 817ms/step - accuracy: 0.9790 - loss: 0.9480 - val_accuracy: 0.9870 - val_loss: 0.7897
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9775 - loss: 0.8216 - val_accuracy: 0.9990 - val_loss: 0.6332
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.9843 - loss: 0.7016 - val_accuracy: 0.9955 - val_loss: 0.5572
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 115s 918ms/step - accuracy: 0.9898 - loss: 0.5987 - val_accuracy: 0.9850 - val_loss: 0.5183
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 335ms/step
# Testing Fold 2 on New Data...
# Found 500 validated image filenames belonging to 5 classes.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# Classification Report - Fold 2 (New Test Data):
#                           precision    recall  f1-score   support
#
#             Dyskeratotic       0.85      0.72      0.78       100
#             Koilocytotic       0.82      0.88      0.85       100
#              Metaplastic       0.89      0.86      0.87       100
#                Parabasal       0.94      1.00      0.97       100
# Superficial-Intermediate       0.95      1.00      0.98       100
#
#                 accuracy                           0.89       500
#                macro avg       0.89      0.89      0.89       500
#             weighted avg       0.89      0.89      0.89       500
#
#
# Training Fold 3/5
# Training class distribution:
#  label
# Dyskeratotic                1600
# Koilocytotic                1600
# Metaplastic                 1600
# Parabasal                   1600
# Superficial-Intermediate    1600
# Name: count, dtype: int64
# Validation class distribution:
#  label
# Dyskeratotic                400
# Koilocytotic                400
# Metaplastic                 400
# Parabasal                   400
# Superficial-Intermediate    400
# Name: count, dtype: int64
# Found 8000 validated image filenames belonging to 5 classes.
# Found 2000 validated image filenames belonging to 5 classes.
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 181s 946ms/step - accuracy: 0.5685 - loss: 2.8708 - val_accuracy: 0.8940 - val_loss: 1.9691
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.8850 - loss: 2.0229 - val_accuracy: 0.9755 - val_loss: 1.6205
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9434 - loss: 1.7369 - val_accuracy: 0.9930 - val_loss: 1.4177
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9604 - loss: 1.5238 - val_accuracy: 0.9840 - val_loss: 1.2677
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.9702 - loss: 1.3329 - val_accuracy: 0.9970 - val_loss: 1.0755
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9732 - loss: 1.1455 - val_accuracy: 0.9620 - val_loss: 1.0587
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9803 - loss: 0.9857 - val_accuracy: 0.9975 - val_loss: 0.7923
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.9799 - loss: 0.8574 - val_accuracy: 0.9930 - val_loss: 0.7000
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9825 - loss: 0.7352 - val_accuracy: 0.9960 - val_loss: 0.5901
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 102s 818ms/step - accuracy: 0.9844 - loss: 0.6327 - val_accuracy: 0.9995 - val_loss: 0.5035
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 273ms/step
# Testing Fold 3 on New Data...
# Found 500 validated image filenames belonging to 5 classes.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 999ms/step
# Classification Report - Fold 3 (New Test Data):
#                           precision    recall  f1-score   support
#
#             Dyskeratotic       0.88      0.74      0.80       100
#             Koilocytotic       0.78      0.93      0.85       100
#              Metaplastic       0.89      0.84      0.87       100
#                Parabasal       0.97      1.00      0.99       100
# Superficial-Intermediate       1.00      0.99      0.99       100
#
#                 accuracy                           0.90       500
#                macro avg       0.90      0.90      0.90       500
#             weighted avg       0.90      0.90      0.90       500
#
#
# Training Fold 4/5
# Training class distribution:
#  label
# Dyskeratotic                1600
# Koilocytotic                1600
# Metaplastic                 1600
# Parabasal                   1600
# Superficial-Intermediate    1600
# Name: count, dtype: int64
# Validation class distribution:
#  label
# Dyskeratotic                400
# Koilocytotic                400
# Metaplastic                 400
# Parabasal                   400
# Superficial-Intermediate    400
# Name: count, dtype: int64
# Found 8000 validated image filenames belonging to 5 classes.
# Found 2000 validated image filenames belonging to 5 classes.
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 842ms/step - accuracy: 0.5714 - loss: 2.8586 - val_accuracy: 0.8920 - val_loss: 2.0739
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 100s 800ms/step - accuracy: 0.8913 - loss: 1.9949 - val_accuracy: 0.9845 - val_loss: 1.5523
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 123s 988ms/step - accuracy: 0.9409 - loss: 1.6850 - val_accuracy: 0.9720 - val_loss: 1.4042
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.9620 - loss: 1.4495 - val_accuracy: 0.9775 - val_loss: 1.2056
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9704 - loss: 1.2329 - val_accuracy: 0.9980 - val_loss: 0.9773
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 124s 992ms/step - accuracy: 0.9766 - loss: 1.0490 - val_accuracy: 0.9935 - val_loss: 0.8391
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 100s 800ms/step - accuracy: 0.9810 - loss: 0.8910 - val_accuracy: 0.9800 - val_loss: 0.7521
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 112s 900ms/step - accuracy: 0.9816 - loss: 0.7570 - val_accuracy: 0.9855 - val_loss: 0.6227
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 119s 956ms/step - accuracy: 0.9834 - loss: 0.6546 - val_accuracy: 0.9800 - val_loss: 0.5624
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9847 - loss: 0.5703 - val_accuracy: 0.9980 - val_loss: 0.4348
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 280ms/step
# Testing Fold 4 on New Data...
# Found 500 validated image filenames belonging to 5 classes.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 990ms/step
# Classification Report - Fold 4 (New Test Data):
#                           precision    recall  f1-score   support
#
#             Dyskeratotic       0.90      0.73      0.81       100
#             Koilocytotic       0.78      0.87      0.82       100
#              Metaplastic       0.85      0.89      0.87       100
#                Parabasal       1.00      1.00      1.00       100
# Superficial-Intermediate       0.97      0.99      0.98       100
#
#                 accuracy                           0.90       500
#                macro avg       0.90      0.90      0.90       500
#             weighted avg       0.90      0.90      0.90       500
#
#
# Training Fold 5/5
# Training class distribution:
#  label
# Dyskeratotic                1600
# Koilocytotic                1600
# Metaplastic                 1600
# Parabasal                   1600
# Superficial-Intermediate    1600
# Name: count, dtype: int64
# Validation class distribution:
#  label
# Dyskeratotic                400
# Koilocytotic                400
# Metaplastic                 400
# Parabasal                   400
# Superficial-Intermediate    400
# Name: count, dtype: int64
# Found 8000 validated image filenames belonging to 5 classes.
# Found 2000 validated image filenames belonging to 5 classes.
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.5270 - loss: 3.0011 - val_accuracy: 0.8875 - val_loss: 2.0339
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 867ms/step - accuracy: 0.8749 - loss: 2.0707 - val_accuracy: 0.9585 - val_loss: 1.6782
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 101s 805ms/step - accuracy: 0.9307 - loss: 1.7783 - val_accuracy: 0.9805 - val_loss: 1.4669
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 101s 804ms/step - accuracy: 0.9642 - loss: 1.5275 - val_accuracy: 0.9770 - val_loss: 1.2981
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9664 - loss: 1.3414 - val_accuracy: 0.9880 - val_loss: 1.1145
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9723 - loss: 1.1621 - val_accuracy: 0.9920 - val_loss: 0.9470
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9807 - loss: 0.9967 - val_accuracy: 0.9700 - val_loss: 0.9029
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9826 - loss: 0.8587 - val_accuracy: 0.9925 - val_loss: 0.7053
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9806 - loss: 0.7474 - val_accuracy: 0.9910 - val_loss: 0.6050
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9865 - loss: 0.6378 - val_accuracy: 0.9905 - val_loss: 0.5382
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 411ms/step
# Testing Fold 5 on New Data...
# Found 500 validated image filenames belonging to 5 classes.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# Classification Report - Fold 5 (New Test Data):
#                           precision    recall  f1-score   support
#
#             Dyskeratotic       0.90      0.74      0.81       100
#             Koilocytotic       0.85      0.86      0.86       100
#              Metaplastic       0.79      0.87      0.83       100
#                Parabasal       0.98      1.00      0.99       100
# Superficial-Intermediate       0.95      1.00      0.98       100
#
#                 accuracy                           0.89       500
#                macro avg       0.90      0.89      0.89       500
#             weighted avg       0.90      0.89      0.89       500
#
#
# Mean Validation Accuracy (Original Data): 0.9927 ± 0.0054
